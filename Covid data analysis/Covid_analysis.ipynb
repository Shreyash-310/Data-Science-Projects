# %% [markdown]
# Referred from here https://python.plainenglish.io/covid-19-a-complete-and-extensive-exploratory-data-analysis-approach-using-python-9b72fc873cc4

# %%
import pandas as pd

# %%
df = pd.read_csv('covid-data.csv')

# %%
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198388 entries, 0 to 198387
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    198388 non-null  object
#  1   continent                                   186885 non-null  object
#  2   location                                    198388 non-null  object
#  3   date                                        198388 non-null  object
#  4   total_cases                                 190456 non-null  float64
#  5   new_cases                                   190174 non-null  float64
#  6   new_cases_smoothed                          188997 non-null  float64
#  7   total_deaths                                171834 non-null  float64
#  8   new_deaths                                  171801 non-null  float64
# ...

# %%
selected_cols=['continent','location', 'date', 'total_cases','new_cases', 'total_deaths', 'new_deaths'
              ,'icu_patients', 'weekly_icu_admissions', 'weekly_hosp_admissions', 'new_tests',
             'total_tests', 'positive_rate', 'total_vaccinations', 'people_vaccinated', 
              'people_fully_vaccinated', 'total_boosters','new_vaccinations', 'population','life_expectancy',
             'excess_mortality']

# %%
selected_dtypes = {
    'continent': 'object',
    'location': 'object',
    'date': 'object',
}

# %%
for col in selected_cols[3:]:
    selected_dtypes[col] = 'float32'

# %%
selected_dtypes
# Out:
# {'continent': 'object',
#  'location': 'object',
#  'date': 'object',
#  'total_cases': 'float32',
#  'new_cases': 'float32',
#  'total_deaths': 'float32',
#  'new_deaths': 'float32',
#  'icu_patients': 'float32',
#  'weekly_icu_admissions': 'float32',
#  'weekly_hosp_admissions': 'float32',
#  'new_tests': 'float32',
#  'total_tests': 'float32',
#  'positive_rate': 'float32',
#  'total_vaccinations': 'float32',
#  'people_vaccinated': 'float32',
#  'people_fully_vaccinated': 'float32',
#  'total_boosters': 'float32',
#  'new_vaccinations': 'float32',
#  'population': 'float32',
#  'life_expectancy': 'float32',
#  'excess_mortality': 'float32'}

# %%
df_last = pd.read_csv('covid-data.csv', usecols=selected_cols, 
                    dtype=selected_dtypes)

# %%
df_last.head()
# Out:
#   continent     location        date  total_cases  new_cases  total_deaths  \
# 0      Asia  Afghanistan  2020-02-24          5.0        5.0           NaN
# 1      Asia  Afghanistan  2020-02-25          5.0        0.0           NaN
# 2      Asia  Afghanistan  2020-02-26          5.0        0.0           NaN
# 3      Asia  Afghanistan  2020-02-27          5.0        0.0           NaN
# 4      Asia  Afghanistan  2020-02-28          5.0        0.0           NaN
#
#    new_deaths  icu_patients  weekly_icu_admissions  weekly_hosp_admissions  \
# 0         NaN           NaN                    NaN                     NaN
# 1         NaN           NaN                    NaN                     NaN
# 2         NaN           NaN                    NaN                     NaN
# 3         NaN           NaN                    NaN                     NaN
# 4         NaN           NaN                    NaN                     NaN
#
# ...

# %%
df_last.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198388 entries, 0 to 198387
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   continent                186885 non-null  object
#  1   location                 198388 non-null  object
#  2   date                     198388 non-null  object
#  3   total_cases              190456 non-null  float32
#  4   new_cases                190174 non-null  float32
#  5   total_deaths             171834 non-null  float32
#  6   new_deaths               171801 non-null  float32
#  7   icu_patients             26286 non-null   float32
#  8   weekly_icu_admissions    6444 non-null    float32
#  9   weekly_hosp_admissions   12843 non-null   float32
#  10  total_tests              79385 non-null   float32
#  11  new_tests                75401 non-null   float32
#  12  positive_rate            95920 non-null   float32
# ...

# %%
dic_country = {}
for country in df_last['location'].unique():
    dic_country[country] = df_last[df_last['location'] == country].copy()

# %%
dic_country['Germany']
# Out:
#       continent location        date  total_cases  new_cases  total_deaths  \
# 66910    Europe  Germany  2020-01-27          1.0        1.0           NaN
# 66911    Europe  Germany  2020-01-28          4.0        3.0           NaN
# 66912    Europe  Germany  2020-01-29          4.0        0.0           NaN
# 66913    Europe  Germany  2020-01-30          4.0        0.0           NaN
# 66914    Europe  Germany  2020-01-31          5.0        1.0           NaN
# ...         ...      ...         ...          ...        ...           ...
# 67793    Europe  Germany  2022-06-28   28048190.0   133950.0      141022.0
# 67794    Europe  Germany  2022-06-29   28180860.0   132671.0      141105.0
# 67795    Europe  Germany  2022-06-30   28293960.0   113099.0      141189.0
# 67796    Europe  Germany  2022-07-01   28392628.0    98669.0      141292.0
# 67797    Europe  Germany  2022-07-02   28392630.0        1.0      141292.0
#
#        new_deaths  icu_patients  weekly_icu_admissions  \
# ...

# %% [markdown]
# 1. When started the pandemic in each country?
# 2. Is it possible to determine, on average, the time when every country in the world had a least one detected case of COVID-19 in their terrotory?

# %%
begin_pan = {}
for i in dic_country.keys():
    loc = dic_country[i]['new_cases'].first_valid_index()
    if loc is not None:
        if df_last.at[loc,'date'] not in begin_pan.keys():
            begin_pan[df_last.at[loc,'date']] = [1]
        else:
            begin_pan[df_last.at[loc,'date']][0] += 1
    else:
        begin_pan[dic_country[i].date.unique()[0]] = [1]

# %%
begin_pan
# Out:
# {'2020-02-24': [5],
#  '2020-02-13': [1],
#  '2020-03-09': [2],
#  '2020-02-25': [5],
#  '2020-03-02': [7],
#  '2020-03-20': [8],
#  '2020-03-28': [3],
#  '2020-03-13': [9],
#  '2020-03-03': [3],
#  '2020-03-01': [1],
#  '2020-01-22': [6],
#  '2020-01-26': [1],
#  '2020-03-16': [5],
#  '2020-03-08': [5],
#  '2020-03-17': [4],
#  '2020-02-28': [5],
#  '2020-02-04': [1],
#  '2020-03-23': [1],
#  '2020-03-19': [7],
#  '2020-03-06': [9],
#  '2020-03-11': [6],
#  '2020-04-02': [2],
#  '2020-03-05': [4],
#  '2020-03-30': [1],
#  '2020-02-26': [6],
#  '2020-03-10': [4],
#  '2020-03-31': [2],
#  '2020-01-27': [3],
#  '2020-01-23': [13],
#  '2020-03-15': [5],
#  '2020-02-23': [2],
#  '2020-04-30': [1],
#  '2021-05-21': [1],
#  '2020-03-12': [2],
#  '2020-03-14': [15],
#  '2020-02-27': [3],
#  '2020-03-18': [5],
#  '2020-03-22': [5],
#  '2020-02-14': [1],
#  '2020-03-21': [2],
#  '2020-03-04': [6],
#  '2020-04-04': [1],
#  '2020-01-29': [2],
#  '2020-01-24': [1],
#  '2021-01-24': [1],
# ...

# %%
pd_begin = pd.DataFrame.from_dict(begin_pan, orient='index', columns=['values'])

# %%
pd_begin
# Out:
#             values
# 2020-02-24       5
# 2020-02-13       1
# 2020-03-09       2
# 2020-02-25       5
# 2020-03-02       7
# ...            ...
# 2021-04-27       1
# 2020-11-10       1
# 2020-10-19       1
# 2022-04-20       1
# 2020-04-10       1
#
# [83 rows x 1 columns]

# %%
pd_begin.index = pd.to_datetime(pd_begin.index)

# %%
pd_begin['year'] = pd.DatetimeIndex(pd_begin.index).year
pd_begin['month'] = pd.DatetimeIndex(pd_begin.index).month
pd_begin['day'] = pd.DatetimeIndex(pd_begin.index).day
pd_begin['weekday'] = pd.DatetimeIndex(pd_begin.index).weekday

# %%
pd_begin
# Out:
#             values  year  month  day  weekday
# 2020-02-24       5  2020      2   24        0
# 2020-02-13       1  2020      2   13        3
# 2020-03-09       2  2020      3    9        0
# 2020-02-25       5  2020      2   25        1
# 2020-03-02       7  2020      3    2        0
# ...            ...   ...    ...  ...      ...
# 2021-04-27       1  2021      4   27        1
# 2020-11-10       1  2020     11   10        1
# 2020-10-19       1  2020     10   19        0
# 2022-04-20       1  2022      4   20        2
# 2020-04-10       1  2020      4   10        4
#
# [83 rows x 5 columns]

# %% [markdown]
# It's not possible that the beginning of the COVID-19 Pandemic for any country began in 2021. Also, we want dates before June, since at that point already every country in the world had more than 1 case detected.

# %%
begin_df = pd_begin[(pd_begin.year == 2020) & (pd_begin.month <= 6)]
begin_df
# Out:
#             values  year  month  day  weekday
# 2020-02-24       5  2020      2   24        0
# 2020-02-13       1  2020      2   13        3
# 2020-03-09       2  2020      3    9        0
# 2020-02-25       5  2020      2   25        1
# 2020-03-02       7  2020      3    2        0
# ...            ...   ...    ...  ...      ...
# 2020-04-06       1  2020      4    6        0
# 2020-02-22       1  2020      2   22        5
# 2020-02-01       2  2020      2    1        5
# 2020-05-01       1  2020      5    1        4
# 2020-04-10       1  2020      4   10        4
#
# [61 rows x 5 columns]

# %%
begin_df = begin_df.sort_values(['month','day'], ascending=True)
begin_df
# Out:
#             values  year  month  day  weekday
# 2020-01-22       6  2020      1   22        2
# 2020-01-23      13  2020      1   23        3
# 2020-01-24       1  2020      1   24        4
# 2020-01-25       3  2020      1   25        5
# 2020-01-26       1  2020      1   26        6
# ...            ...   ...    ...  ...      ...
# 2020-04-06       1  2020      4    6        0
# 2020-04-10       1  2020      4   10        4
# 2020-04-30       1  2020      4   30        3
# 2020-05-01       1  2020      5    1        4
# 2020-05-13       1  2020      5   13        2
#
# [61 rows x 5 columns]

# %%
import plotly.express as px

# %%
fig = px.histogram(begin_df, x=begin_df.index, y='values', marginal='box')
#fig(figsize=(15,15))
fig.update_layout(title='1. Beginning of Covid 19 around World',
                  xaxis_title='Date',
                  yaxis_title='Count',
                  plot_bgcolor='beige',
                  font=dict(family='Arial', size=14, color='darkblue'))
fig.show()

# %% [markdown]
# Conclusion :-
# 1) As we already know, Covid-19 was discovered in December 2019, but it started propagating through the world at the beginning of 2020. It is possible that the first 30 countries to receive the virus between January 19th to February 2nd were from Asia. But we should be careful because when we were counting the beginning dates in each country we needed to include a statement, in which if we can not extract the information required, we just appended the first date we get for that specific country. One example of this situation can be found for Anguilla, which has no data for the first column of the dataset.
# 2) Almost a third part of the world had an increase of new cases in the first half of March, and almost every country in the world had at least one new case by the end of April.

# %% [markdown]
# Cleaning the dataset

# %%
df_last['date'] = pd.to_datetime(df_last['date'])

# %%
df_last = df_last.fillna(0)

# %%
df_last.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198388 entries, 0 to 198387
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   continent                198388 non-null  object
#  1   location                 198388 non-null  object
#  2   date                     198388 non-null  datetime64[ns]
#  3   total_cases              198388 non-null  float32
#  4   new_cases                198388 non-null  float32
#  5   total_deaths             198388 non-null  float32
#  6   new_deaths               198388 non-null  float32
#  7   icu_patients             198388 non-null  float32
#  8   weekly_icu_admissions    198388 non-null  float32
#  9   weekly_hosp_admissions   198388 non-null  float32
#  10  total_tests              198388 non-null  float32
#  11  new_tests                198388 non-null  float32
#  12  positive_rate            198388 non-null  float32
# ...

# %%
dic_country = {}
for country in df_last.location.unique():
    dic_country[country] = df_last[df_last.location == country].copy()

# %% [markdown]
# Analyzing Mexico, North and South America

# %% [markdown]
# 3.Since Mexico is the only Latin American country considered, by its geographical location, as part of the North America region, which trending will Mexico follow through the pandemic: as a North American country or as an average Latin America country? Why?
#
# 4.Why could not we consider both regions als one only America region for the purpose of our study?

# %%
import folium

# %%
m = folium.Map(location=[19.42847,-99.12766], zoom_start=3)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
result = pd.concat([dic_country['Mexico'].set_index('date'),dic_country['South America'].set_index('date'),
                   dic_country['North America'].set_index('date')],axis=1, join='inner')

# %%
result.head()
# Out:
#                 continent location  total_cases  new_cases  total_deaths  \
# date
# 2020-02-22  North America   Mexico          0.0        0.0           0.0
# 2020-02-23  North America   Mexico          0.0        0.0           0.0
# 2020-02-24  North America   Mexico          0.0        0.0           0.0
# 2020-02-25  North America   Mexico          0.0        0.0           0.0
# 2020-02-26  North America   Mexico          0.0        0.0           0.0
#
#             new_deaths  icu_patients  weekly_icu_admissions  \
# date
# 2020-02-22         0.0           0.0                    0.0
# 2020-02-23         0.0           0.0                    0.0
# 2020-02-24         0.0           0.0                    0.0
# 2020-02-25         0.0           0.0                    0.0
# 2020-02-26         0.0           0.0                    0.0
#
#             weekly_hosp_admissions  total_tests  ...  new_tests  \
# date                                             ...
# ...

# %%
t_cases = result['total_cases']
t_cases.columns = ['Mexico','Latin America','North America']
t_cases
# Out:
#                Mexico  Latin America  North America
# date
# 2020-02-22        0.0            0.0           30.0
# 2020-02-23        0.0            2.0           31.0
# 2020-02-24        0.0            2.0           32.0
# 2020-02-25        0.0            2.0           35.0
# 2020-02-26        0.0            3.0           36.0
# ...               ...            ...            ...
# 2022-06-28  5986917.0     59432312.0    103052368.0
# 2022-06-29  5986917.0     59450244.0    103259848.0
# 2022-06-30  6034602.0     59643724.0    103458056.0
# 2022-07-01  6058689.0     59736848.0    103688272.0
# 2022-07-02  6058689.0     59791472.0    103710240.0
#
# [862 rows x 3 columns]

# %%
fig = px.line(t_cases, title = '2. Total cases in Mexico, Latin and orth Aemrica',
              color_discrete_sequence=["aquamarine", "cornflowerblue", "goldenrod"])

fig.update_layout(
    xaxis_title = "Date",
    yaxis_title = "Total Cases",
    plot_bgcolor = "MintCream",
    font = dict(family='Arial',size=14,color='darkblue')
) 

fig.show()

# %%
new_cases=result['new_cases']
new_cases.columns=['Mexico', 'Latin America', 'North America']

fig2 = px.bar(new_cases, 
              title='3. New Cases in Mexico, Latin and North America', 
              color_discrete_sequence=["Gold", "IndianRed", "MediumTurquoise"])

fig2.update_layout(
    xaxis_title="Date",
    yaxis_title="New Cases",
    plot_bgcolor='SeaShell',
    font=dict(
        family="Arial",
        size=14,
        color="darkblue"
    )
)

fig2.show()

# %% [markdown]
# USA and Vaccines

# %% [markdown]
# 5. Having USA a high acces to different vaccines for their population, is this nation near to the end of the pandemic?
#
# 6. Is there a correlation between new vaccinated people, distribuited vaccines and new deaths?

# %%
vac_usa = pd.read_csv('vaccine_details.csv')
vac_usa.head()
# Out:
#                       date  mmwr_week location  distributed  \
# 0  2022-06-29T00:00:00.000         26       GU       330560
# 1  2022-06-29T00:00:00.000         26       NM      4747945
# 2  2022-06-29T00:00:00.000         26       DE      2521155
# 3  2022-06-29T00:00:00.000         26       MI     22699210
# 4  2022-06-29T00:00:00.000         26       CA     95539455
#
#    distributed_janssen  distributed_moderna  distributed_pfizer  \
# 0                24100                88480              217980
# 1               188400              1843600             2715945
# 2               100800               977600             1442755
# 3               949600              9043020            12706590
# 4              3742600             34371680            57425175
#
#    distributed_unk_manuf  dist_per_100k  distributed_per_100k_5plus  ...  \
# 0                      0         196191                      216390  ...
# ...

# %%
selected_cols=['Date','Distributed', 'Distributed_Janssen','Distributed_Moderna','Distributed_Pfizer'
               ,'Distributed_Unk_Manuf']

selected_dtypes={
    'Date':'object',
    'Distributed':'int32',
    'Distributed_Janssen':'int32',
    'Distributed_Moderna':'int32',
    'Distributed_Pfizer':'int32',
    'Distributed_Unk_Manuf':'int32'
}

"""selected_cols=['date','distributed', 'distributed_janssen','distributed_moderna','distributed_pfizer','distributed_unk_manuf']

selected_dtypes={
    'date':'object',
    'distributed':'int32',
    'distributed_janssen':'int32',
    'distributed_moderna':'int32',
    'distributed_pfizer':'int32',
    'distributed_unk_manuf':'int32'
}"""
# Out:
# "selected_cols=['date','distributed', 'distributed_janssen','distributed_moderna','distributed_pfizer','distributed_unk_manuf']\n\nselected_dtypes={\n    'date':'object',\n    'distributed':'int32',\n    'distributed_janssen':'int32',\n    'distributed_moderna':'int32',\n    'distributed_pfizer':'int32',\n    'distributed_unk_manuf':'int32'\n}"

# %%
df_vac = pd.read_csv('vaccine_details.csv', usecols=selected_cols, dtype=selected_dtypes)

# %%
df_vac
# Out:
#                         Date  Distributed  Distributed_Janssen  \
# 0    2022-06-29T00:00:00.000       330560                24100
# 1    2022-06-29T00:00:00.000      4747945               188400
# 2    2022-06-29T00:00:00.000      2521155               100800
# 3    2022-06-29T00:00:00.000     22699210               949600
# 4    2022-06-29T00:00:00.000     95539455              3742600
# ..                       ...          ...                  ...
# 995  2022-06-03T00:00:00.000     22806800               935200
# 996  2022-06-03T00:00:00.000      6377680               255500
# 997  2022-06-03T00:00:00.000     11980705               431100
# 998  2022-06-03T00:00:00.000     10876475               456400
# 999  2022-06-03T00:00:00.000      6452050               249000
#
#      Distributed_Moderna  Distributed_Pfizer  Distributed_Unk_Manuf
# 0                  88480              217980                      0
# 1                1843600             2715945                      0
# ...

# %%
vaccines=df_vac.groupby('Date')[['Distributed', 'Distributed_Janssen','Distributed_Moderna','Distributed_Pfizer'
               ,'Distributed_Unk_Manuf']].sum()

# %%
vaccines.index = pd.to_datetime(vaccines.index)
vaccines
# Out:
#             Distributed  Distributed_Janssen  Distributed_Moderna  \
# Date
# 2022-06-03   1252300795             52132100            466625820
# 2022-06-04   1520339360             62689700            565779060
# 2022-06-05   1520377160             62689700            565779260
# 2022-06-06   1520377160             62689700            565779260
# 2022-06-07   1521715460             62694500            566329960
# 2022-06-08   1523129460             62700200            566676760
# 2022-06-09   1525729760             62736800            568554860
# 2022-06-10   1528270460             62742400            569415160
# 2022-06-11   1529810260             62745600            569672960
# 2022-06-12   1529853260             62745600            569676360
# 2022-06-13   1529854960             62745800            569676360
# 2022-06-14   1531186660             62753000            570145760
# 2022-06-15   1532482760             62758800            570676260
# ...

# %%
usa_df=pd.concat([dic_country['United States'].set_index('date'), vaccines], axis=1, join="inner")
usa_df.head()
# Out:
#                 continent       location  total_cases  new_cases  \
# 2022-06-03  North America  United States   84810752.0   157807.0
# 2022-06-04  North America  United States   84837208.0    26457.0
# 2022-06-05  North America  United States   84852000.0    14791.0
# 2022-06-06  North America  United States   85014696.0   162699.0
# 2022-06-07  North America  United States   85101456.0    86758.0
#
#             total_deaths  new_deaths  icu_patients  weekly_icu_admissions  \
# 2022-06-03     1008580.0       398.0        2721.0                    0.0
# 2022-06-04     1008735.0       155.0        2669.0                    0.0
# 2022-06-05     1008757.0        22.0        2603.0                    0.0
# 2022-06-06     1009035.0       278.0        2738.0                    0.0
# 2022-06-07     1009507.0       472.0        2810.0                    0.0
#
#             weekly_hosp_admissions  total_tests  ...  total_boosters  \
# ...

# %%
usa_df['year'] = pd.DatetimeIndex(usa_df.index).year
usa_df['month'] = pd.DatetimeIndex(usa_df.index).month
usa_df['day'] = pd.DatetimeIndex(usa_df.index).day

# %%
usa_df.head()
# Out:
#                 continent       location  total_cases  new_cases  \
# 2022-06-03  North America  United States   84810752.0   157807.0
# 2022-06-04  North America  United States   84837208.0    26457.0
# 2022-06-05  North America  United States   84852000.0    14791.0
# 2022-06-06  North America  United States   85014696.0   162699.0
# 2022-06-07  North America  United States   85101456.0    86758.0
#
#             total_deaths  new_deaths  icu_patients  weekly_icu_admissions  \
# 2022-06-03     1008580.0       398.0        2721.0                    0.0
# 2022-06-04     1008735.0       155.0        2669.0                    0.0
# 2022-06-05     1008757.0        22.0        2603.0                    0.0
# 2022-06-06     1009035.0       278.0        2738.0                    0.0
# 2022-06-07     1009507.0       472.0        2810.0                    0.0
#
#             weekly_hosp_admissions  total_tests  ...  life_expectancy  \
# ...

# %% [markdown]
# Visualization of the data

# %%
fig_vac=px.treemap(
    usa_df,
    path=['location', 'month','new_cases'],
    color='Distributed', 
    color_continuous_scale='RdBu',
    title='4. Treemap for USA new cases monthly and vaccines distributed'

)
fig_vac.show()
# Out:
# /home/mytsl02451/.local/lib/python3.8/site-packages/plotly/express/_core.py:1637: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/mytsl02451/.local/lib/python3.8/site-packages/plotly/express/_core.py:1637: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/mytsl02451/.local/lib/python3.8/site-packages/plotly/express/_core.py:1637: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %%
fig = px.sunburst(usa_df, 
                 path=['month', 'new_vaccinations'], 
                 values='new_deaths',
                 color='Distributed', 
                 color_continuous_scale='RdBu',
                 title='5. Pie Chart for possible correlation between vaccinations and deaths')
fig.show()
# Out:
# /home/mytsl02451/.local/lib/python3.8/site-packages/plotly/express/_core.py:1637: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/mytsl02451/.local/lib/python3.8/site-packages/plotly/express/_core.py:1637: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %%
fig=px.scatter_3d(usa_df, 
              x=usa_df.index, 
              y='Distributed', 
              z='new_deaths',
              title='6. 3D Graphic of distributed vaccines and new deaths in USA')
fig.update_layout(
    font=dict(
        family="Arial",
        size=14,
        color="darkblue"
    )
)
fig.show()

# %%
type_vaccines=usa_df[['Distributed_Janssen', 'Distributed_Pfizer', 'Distributed_Moderna']]
pd.options.plotting.backend = "plotly"

# %%
fig=px.line(type_vaccines, title='7. Vaccines in USA')
fig.update_layout(
    xaxis_title="Date",
    yaxis_title="Vaccines",
    plot_bgcolor='GhostWhite',
    font=dict(
        family="Arial",
        size=14,
        color="darkblue"
    )
)
fig.show()

# %% [markdown]
# UK and hospitalitations

# %% [markdown]
# 7. Since UK is one of the countries with data about ICU patients available, can we figure out how vaccines work to decrease the number of patients in the hospitals?

# %%
uk_df=dic_country['United Kingdom']
uk_df
# Out:
#        continent        location       date  total_cases  new_cases  \
# 186034    Europe  United Kingdom 2020-01-31          2.0        2.0
# 186035    Europe  United Kingdom 2020-02-01          2.0        0.0
# 186036    Europe  United Kingdom 2020-02-02          2.0        0.0
# 186037    Europe  United Kingdom 2020-02-03          8.0        6.0
# 186038    Europe  United Kingdom 2020-02-04          8.0        0.0
# ...          ...             ...        ...          ...        ...
# 186913    Europe  United Kingdom 2022-06-28   22739876.0    21412.0
# 186914    Europe  United Kingdom 2022-06-29   22777114.0    37239.0
# 186915    Europe  United Kingdom 2022-06-30   22800022.0    22908.0
# 186916    Europe  United Kingdom 2022-07-01   22822056.0    22033.0
# 186917    Europe  United Kingdom 2022-07-02   22822056.0        0.0
#
#         total_deaths  new_deaths  icu_patients  weekly_icu_admissions  \
# 186034           0.0         0.0           0.0                    0.0
# ...

# %%
fig=px.scatter(uk_df, 
           x="date", 
           y="icu_patients", 
           size='people_vaccinated', 
           title='8. ICU cases in UK'
           )
fig.update_layout(
    xaxis_title="Date",
    yaxis_title="ICU Patients",
    plot_bgcolor='Gold',
    font=dict(
        family="Arial",
        size=14,
        color="darkblue"
    )
)
fig.show()

# %%
fig=px.scatter(uk_df[uk_df['weekly_hosp_admissions'] !=0], 
           x="date", 
           y="weekly_hosp_admissions", 
           size='people_vaccinated', 
           title='9. Weekly hospitalitation cases in UK',
           color_discrete_sequence=['magenta']
           )
fig.update_layout(
    xaxis_title="Date",
    yaxis_title="Weekly Hospitalitations",
    plot_bgcolor='lightblue',
    font=dict(
        family="Arial",
        size=14,
        color="darkblue"
    )
)
fig.show()

# %% [markdown]
# United Arab Emirates and New Zealand: Success beyond vaccines

# %% [markdown]
# 8. Before vaccines were available worldwide, New Zealand and UAE have great succes controlling the virus propagation in their population. How can they do that?

# %%
uae_df = dic_country['United Arab Emirates']
nz_df = dic_country['New Zealand']

# %%
uae_df[['new_cases','new_deaths','new_tests','population']].describe()
# Out:
#          new_cases  new_deaths      new_tests  population
# count   886.000000  886.000000     886.000000       886.0
# mean   1071.539551    2.615124  190206.171875   9991082.0
# std     942.438965    3.271821  127806.109375         0.0
# min       0.000000    0.000000       0.000000   9991083.0
# 25%     290.000000    0.000000   72309.250000   9991083.0
# 50%     837.500000    2.000000  194531.000000   9991083.0
# 75%    1619.500000    4.000000  282290.000000   9991083.0
# max    4471.000000   20.000000  563330.000000   9991083.0

# %%
nz_df[['new_cases','new_deaths','new_tests','population']].describe()
# Out:
#           new_cases  new_deaths     new_tests  population
# count    856.000000  856.000000    856.000000       856.0
# mean    1586.293213    1.758178   4974.385742   5126299.5
# std     4500.762695    5.040299   7702.152344         0.0
# min        0.000000    0.000000      0.000000   5126300.0
# 25%        1.000000    0.000000      0.000000   5126300.0
# 50%        6.000000    0.000000   2313.000000   5126300.0
# 75%       83.000000    0.000000   6064.250000   5126300.0
# max    39773.000000   35.000000  52117.000000   5126300.0

# %%
fig=px.line(uae_df[uae_df['people_fully_vaccinated'] !=0],
           x='date',
           y='people_fully_vaccinated',
           title='10. Full vaccinated people in UAE'
           
           )
fig.update_layout(
        xaxis_title='Date',
        yaxis_title='Number of people fully vaccinated',
        plot_bgcolor='lightblue',
    font=dict(
        family="Arial",
        size=14,
        color="darkblue"
    )
)
fig.show()

# %% [markdown]
# More than 90% of UAE population has been fully vaccinated

# %%
fig=px.line(nz_df[nz_df['people_fully_vaccinated'] !=0],
           x='date',
           y='people_fully_vaccinated',
           title='11. Full vaccinated people in New Zealand'
           
           )
fig.update_layout(
        xaxis_title='Date',
        yaxis_title='Number of people fully vaccinated',
        plot_bgcolor='lightblue',
    font=dict(
        family="Arial",
        size=14,
        color="darkblue"
    )
)
fig.show()

# %% [markdown]
# 1.- Vaccines are helping to reduce hospitalitations, but without better regulations most of the countries will face some peaks in new deaths and new hospitalitations, which will prolong the quarantine
#
# 2.- Continents should work as a unity, in oder to reach favorable behaviours like the ones we see in some islands like New Zealand and UK
#
# 3.- Pandas and Plotly allowed us to understand better the situation around COVID-10 Pandemic. Most of the resources can be found as CSV files, which is a good advantage to realize some exploratory data analysis
